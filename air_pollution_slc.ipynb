# %% [markdown]
# The basic idea of this project is to examine the air pollution in Salt Lake City, Utah, in a given time period. For now I have somewhat arbitrarily chosen the year 2008, but may change this depending on what comes from this. I would also like to explore how traffic patterns in Salt Lake affect the air pollution.

# %%
# !ls
# Out:
# 2008_Ozone.csv  2008_PM10.csv   2008_PM2pt5.csv Untitled.ipynb

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## First we collect data on PM2.5

# %%
df1 = pd.read_csv('2008_PM2pt5.csv')

df1.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM2.5 Concentration':'PM2.5'}, axis='columns', inplace=True)
df1 = df1[['Date','PM2.5']]
df1['Date'] = pd.to_datetime(df1['Date'])

df1 = df1.groupby('Date').mean()
df1.reset_index(inplace=True)
##################################################
df2 = pd.read_csv('2009_PM2pt5.csv')

df2.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM2.5 Concentration':'PM2.5'}, axis='columns', inplace=True)
df2 = df2[['Date','PM2.5']]
df2['Date'] = pd.to_datetime(df2['Date'])

df2 = df2.groupby('Date').mean()
df2.reset_index(inplace=True)
##################################################


df3 = pd.read_csv('2010_PM2pt5.csv')

df3.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM2.5 Concentration':'PM2.5'}, axis='columns', inplace=True)
df3 = df3[['Date','PM2.5']]
df3['Date'] = pd.to_datetime(df3['Date'])

df3 = df3.groupby('Date').mean()
df3.reset_index(inplace=True)
##################################################


df4 = pd.read_csv('2011_PM2pt5.csv')

df4.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM2.5 Concentration':'PM2.5'}, axis='columns', inplace=True)
df4 = df4[['Date','PM2.5']]
df4['Date'] = pd.to_datetime(df4['Date'])

df4 = df4.groupby('Date').mean()
df4.reset_index(inplace=True)
##################################################


df5 = pd.read_csv('2012_PM2pt5.csv')

df5.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM2.5 Concentration':'PM2.5'}, axis='columns', inplace=True)
df5 = df5[['Date','PM2.5']]
df5['Date'] = pd.to_datetime(df5['Date'])

df5 = df5.groupby('Date').mean()
df5.reset_index(inplace=True)
##################################################


df6 = pd.read_csv('2013_PM2pt5.csv')

df6.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM2.5 Concentration':'PM2.5'}, axis='columns', inplace=True)
df6 = df6[['Date','PM2.5']]
df6['Date'] = pd.to_datetime(df6['Date'])

df6 = df6.groupby('Date').mean()
df6.reset_index(inplace=True)
##################################################



df7 = pd.read_csv('2014_PM2pt5.csv')

df7.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM2.5 Concentration':'PM2.5'}, axis='columns', inplace=True)
df7 = df7[['Date','PM2.5']]
df7['Date'] = pd.to_datetime(df7['Date'])

df7 = df7.groupby('Date').mean()
df7.reset_index(inplace=True)
##################################################


df8 = pd.read_csv('2015_PM2pt5.csv')

df8.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM2.5 Concentration':'PM2.5'}, axis='columns', inplace=True)
df8 = df8[['Date','PM2.5']]
df8['Date'] = pd.to_datetime(df8['Date'])

df8 = df8.groupby('Date').mean()
df8.reset_index(inplace=True)
##################################################

# %% [markdown]
# ## I am not getting good results, so I'm going to try scaling the PM2.5 data, to make it more visible relative to the other pollutant graphs

# %%
df_25 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8])

# %%
df_25['PM2.5'] = df_25['PM2.5']*2

# %% [markdown]
# ## Then on PM10

# %%
df1 = pd.read_csv('2008_PM10.csv')

df1.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM10 Concentration':'PM10'}, axis='columns', inplace=True)
df1 = df1[['Date','PM10']]
df1['Date'] = pd.to_datetime(df1['Date'])

df1 = df1.groupby('Date').mean()
df1.reset_index(inplace=True)
##################################################
df2 = pd.read_csv('2009_PM10.csv')

df2.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM10 Concentration':'PM10'}, axis='columns', inplace=True)
df2 = df2[['Date','PM10']]
df2['Date'] = pd.to_datetime(df2['Date'])

df2 = df2.groupby('Date').mean()
df2.reset_index(inplace=True)
##################################################


df3 = pd.read_csv('2010_PM10.csv')

df3.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM10 Concentration':'PM10'}, axis='columns', inplace=True)
df3 = df3[['Date','PM10']]
df3['Date'] = pd.to_datetime(df3['Date'])

df3 = df3.groupby('Date').mean()
df3.reset_index(inplace=True)
##################################################


df4 = pd.read_csv('2011_PM10.csv')

df4.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM10 Concentration':'PM10'}, axis='columns', inplace=True)
df4 = df4[['Date','PM10']]
df4['Date'] = pd.to_datetime(df4['Date'])

df4 = df4.groupby('Date').mean()
df4.reset_index(inplace=True)
##################################################


df5 = pd.read_csv('2012_PM10.csv')

df5.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM10 Concentration':'PM10'}, axis='columns', inplace=True)
df5 = df5[['Date','PM10']]
df5['Date'] = pd.to_datetime(df5['Date'])

df5 = df5.groupby('Date').mean()
df5.reset_index(inplace=True)
##################################################


df6 = pd.read_csv('2013_PM10.csv')

df6.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM10 Concentration':'PM10'}, axis='columns', inplace=True)
df6 = df6[['Date','PM10']]
df6['Date'] = pd.to_datetime(df6['Date'])

df6 = df6.groupby('Date').mean()
df6.reset_index(inplace=True)
##################################################



df7 = pd.read_csv('2014_PM10.csv')

df7.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM10 Concentration':'PM10'}, axis='columns', inplace=True)
df7 = df7[['Date','PM10']]
df7['Date'] = pd.to_datetime(df7['Date'])

df7 = df7.groupby('Date').mean()
df7.reset_index(inplace=True)
##################################################


df8 = pd.read_csv('2015_PM10.csv')

df8.rename({'AQS_SITE_ID':'Site', 'Daily Mean PM10 Concentration':'PM10'}, axis='columns', inplace=True)
df8 = df8[['Date','PM10']]
df8['Date'] = pd.to_datetime(df8['Date'])

df8 = df8.groupby('Date').mean()
df8.reset_index(inplace=True)
##################################################

# %%
df_10 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8])

# %% [markdown]
# ## Carbon Monoxide (CO)

# %%
df1 = pd.read_csv('2008_CO.csv')

df1.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour CO Concentration':'CO'}, axis='columns', inplace=True)
df1 = df1[['Date','CO']]
df1['Date'] = pd.to_datetime(df1['Date'])

df1 = df1.groupby('Date').mean()
df1.reset_index(inplace=True)
##################################################
df2 = pd.read_csv('2009_CO.csv')

df2.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour CO Concentration':'CO'}, axis='columns', inplace=True)
df2 = df2[['Date','CO']]
df2['Date'] = pd.to_datetime(df2['Date'])

df2 = df2.groupby('Date').mean()
df2.reset_index(inplace=True)
##################################################


df3 = pd.read_csv('2010_CO.csv')

df3.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour CO Concentration':'CO'}, axis='columns', inplace=True)
df3 = df3[['Date','CO']]
df3['Date'] = pd.to_datetime(df3['Date'])

df3 = df3.groupby('Date').mean()
df3.reset_index(inplace=True)
##################################################


df4 = pd.read_csv('2011_CO.csv')

df4.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour CO Concentration':'CO'}, axis='columns', inplace=True)
df4 = df4[['Date','CO']]
df4['Date'] = pd.to_datetime(df4['Date'])

df4 = df4.groupby('Date').mean()
df4.reset_index(inplace=True)
##################################################


df5 = pd.read_csv('2012_CO.csv')

df5.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour CO Concentration':'CO'}, axis='columns', inplace=True)
df5 = df5[['Date','CO']]
df5['Date'] = pd.to_datetime(df5['Date'])

df5 = df5.groupby('Date').mean()
df5.reset_index(inplace=True)
##################################################


df6 = pd.read_csv('2013_CO.csv')

df6.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour CO Concentration':'CO'}, axis='columns', inplace=True)
df6 = df6[['Date','CO']]
df6['Date'] = pd.to_datetime(df6['Date'])

df6 = df6.groupby('Date').mean()
df6.reset_index(inplace=True)
##################################################



df7 = pd.read_csv('2014_CO.csv')

df7.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour CO Concentration':'CO'}, axis='columns', inplace=True)
df7 = df7[['Date','CO']]
df7['Date'] = pd.to_datetime(df7['Date'])

df7 = df7.groupby('Date').mean()
df7.reset_index(inplace=True)
##################################################


df8 = pd.read_csv('2015_CO.csv')

df8.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour CO Concentration':'CO'}, axis='columns', inplace=True)
df8 = df8[['Date','CO']]
df8['Date'] = pd.to_datetime(df8['Date'])

df8 = df8.groupby('Date').mean()
df8.reset_index(inplace=True)
##################################################

# %%
df_CO = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8])

# %%
df_CO['CO'] = df_CO['CO']*40

# %% [markdown]
# ## Finally on Ozone levels

# %%
df1 = pd.read_csv('2008_Ozone.csv')

df1.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour Ozone Concentration':'Ozone'}, axis='columns', inplace=True)
df1 = df1[['Date','Ozone']]
df1['Date'] = pd.to_datetime(df1['Date'])

df1 = df1.groupby('Date').mean()
df1.reset_index(inplace=True)
##################################################
df2 = pd.read_csv('2009_Ozone.csv')

df2.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour Ozone Concentration':'Ozone'}, axis='columns', inplace=True)
df2 = df2[['Date','Ozone']]
df2['Date'] = pd.to_datetime(df2['Date'])

df2 = df2.groupby('Date').mean()
df2.reset_index(inplace=True)
##################################################


df3 = pd.read_csv('2010_Ozone.csv')

df3.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour Ozone Concentration':'Ozone'}, axis='columns', inplace=True)
df3 = df3[['Date','Ozone']]
df3['Date'] = pd.to_datetime(df3['Date'])

df3 = df3.groupby('Date').mean()
df3.reset_index(inplace=True)
##################################################


df4 = pd.read_csv('2011_Ozone.csv')

df4.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour Ozone Concentration':'Ozone'}, axis='columns', inplace=True)
df4 = df4[['Date','Ozone']]
df4['Date'] = pd.to_datetime(df4['Date'])

df4 = df4.groupby('Date').mean()
df4.reset_index(inplace=True)
##################################################


df5 = pd.read_csv('2012_Ozone.csv')

df5.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour Ozone Concentration':'Ozone'}, axis='columns', inplace=True)
df5 = df5[['Date','Ozone']]
df5['Date'] = pd.to_datetime(df5['Date'])

df5 = df5.groupby('Date').mean()
df5.reset_index(inplace=True)
##################################################


df6 = pd.read_csv('2013_Ozone.csv')

df6.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour Ozone Concentration':'Ozone'}, axis='columns', inplace=True)
df6 = df6[['Date','Ozone']]
df6['Date'] = pd.to_datetime(df6['Date'])

df6 = df6.groupby('Date').mean()
df6.reset_index(inplace=True)
##################################################



df7 = pd.read_csv('2014_Ozone.csv')

df7.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour Ozone Concentration':'Ozone'}, axis='columns', inplace=True)
df7 = df7[['Date','Ozone']]
df7['Date'] = pd.to_datetime(df7['Date'])

df7 = df7.groupby('Date').mean()
df7.reset_index(inplace=True)
##################################################


df8 = pd.read_csv('2015_Ozone.csv')

df8.rename({'AQS_SITE_ID':'Site', 'Daily Max 8-hour Ozone Concentration':'Ozone'}, axis='columns', inplace=True)
df8 = df8[['Date','Ozone']]
df8['Date'] = pd.to_datetime(df8['Date'])

df8 = df8.groupby('Date').mean()
df8.reset_index(inplace=True)
##################################################

# %%
df_Ozone = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8])

# %% [markdown]
# ## Unfortunately the scale of Ozone is very different from the other two, so we need to scale it in order to plot all three on the same axes

# %%
df_Ozone['Ozone'] = df_Ozone['Ozone']*700

# %%
# %matplotlib inline
import matplotlib.pyplot as plt




plt.figure(figsize=(15,5))

p1 = plt.plot(df_25['Date'], df_25['PM2.5'], color='darkcyan', alpha=0.75, label="Mean PM2.5")
p2 = plt.plot(df_10['Date'], df_10['PM10'],color='darkblue', alpha = 0.4, label="Mean PM10")
p3 = plt.plot(df_Ozone['Date'], df_Ozone['Ozone'],color='red', alpha = 0.7, label="Mean Ozone")


#p3 = plt.plot_date(edays['Date'], edays['Data_Value'], color='tomato', label='Days in 2015')





#p3 = plt.plot_date(new_max['Date'], new_max['Data_Value'],color='red')
#p4 = plt.plot_date(new_min['Date'], new_min['Data_Value'], color='yellow')


#d = maxy['Date'].values
#plt.fill_between(d, maxy['Data_Value'], minny['Data_Value'], facecolor='lightblue', alpha=0.75, interpolate=True)

plt.xticks(rotation=25)
#plt.legend(['highs in 2005-2014','lows in 2005-2014'])


ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
plt.legend()

plt.xlabel('Years')
plt.ylabel('ug/m3 LC, ppm (Ozone)')
plt.title('Air pollution in SLC from 2008 thru 2015')
# Out:
# Text(0.5,1,'Air pollution in SLC from 2008 thru 2015')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt




plt.figure(figsize=(15,5))

p1 = plt.plot(df_25['Date'], df_25['PM2.5'], color='darkcyan', alpha=0.75, label="Mean PM2.5")
p2 = plt.plot(df_CO['Date'], df_CO['CO'],color='darkblue', alpha = 0.4, label="Carbon Monoxide")
p3 = plt.plot(df_Ozone['Date'], df_Ozone['Ozone'],color='red', alpha = 0.7, label="Ozone")


#p3 = plt.plot_date(edays['Date'], edays['Data_Value'], color='tomato', label='Days in 2015')





#p3 = plt.plot_date(new_max['Date'], new_max['Data_Value'],color='red')
#p4 = plt.plot_date(new_min['Date'], new_min['Data_Value'], color='yellow')


#d = maxy['Date'].values
#plt.fill_between(d, maxy['Data_Value'], minny['Data_Value'], facecolor='lightblue', alpha=0.75, interpolate=True)

plt.xticks(rotation=25)
#plt.legend(['highs in 2005-2014','lows in 2005-2014'])


ax = plt.gca()
ax.set_facecolor('xkcd:light grey')
plt.legend()

plt.xlabel('Years')
plt.ylabel('ug/m3 LC, ppm (Ozone)')
plt.title('Air pollution in SLC from 2008 thru 2015')
# Out:
# Text(0.5,1,'Air pollution in SLC from 2008 thru 2015')
